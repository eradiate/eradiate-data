# %% [markdown]
# # CKD absorption data manipulation

# %%
import xarray as xr

ds = xr.open_dataset("afgl1986-us_standard-10nm.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (bd: 128, z: 49)
# Coordinates:
#   * z        (z) float64 0.5 1.5 2.5 3.5 4.5 ... 97.5 102.5 107.5 112.5 117.5
#     bin      (bd) object ...
#     index    (bd) int64 ...
# Dimensions without coordinates: bd
# Data variables:
#     k        (z, bd) float64 ...
#     weight   (bd) float64 ...
#     wmin     (bd) float64 ...
#     wmax     (bd) float64 ...
# Attributes:
#     Conventions:  CF 1.8
#     title:        CKD absorption spectrum - AFGL (1986) US Standard
#     history:      Data set creation - 2021-07-18 10:14:59.981280

# %%
ds.attrs["bin_set"] = "10nm_test"

# %%
ds.to_netcdf("afgl1986-us_standard-10nm_test.nc")
